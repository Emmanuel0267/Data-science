# %%
import pandas as pd
df=  pd.read_csv("C:\\Users\\pc\\Downloads\\heart.csv")
df.head()
import numpy as np

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df[df.RestingBP>(df.RestingBP.mean()+3*df.RestingBP.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 109    106              N      0.0       Up             0
# 241    142              Y      2.0     Flat             1
# 365    140              Y      1.0     Flat             1
# 399     70              N      0.0     Flat             1
# 592    150              Y      2.0     Down             1
# ...

# %%
df1= df[df.RestingBP<=(df.RestingBP.mean()+3*df.RestingBP.std())]
df1.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df1.shape
# Out:
# (911, 12)

# %%
df[df.Cholesterol>(df.Cholesterol.mean() + 3*df.Cholesterol.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 76     130              N      0.0     Flat             1
# 149    125              Y      1.0     Flat             1
# 616    160              N      1.6     Flat             0

# %%
df2 = df1[df1.Cholesterol<=(df1.Cholesterol.mean()+3*df1.Cholesterol.std())]
df2.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df2.shape
# Out:
# (908, 12)

# %%
df[df.MaxHR<(df.MaxHR.mean()-3*df.MaxHR.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 390   51   M           ASY        140            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 390     60              N      0.0     Flat             1

# %%
df[df.Oldpeak>(df.Oldpeak.mean()+3*df.Oldpeak.std())]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 166    140              Y      5.0     Flat             1
# 702    145              N      4.2     Down             0
# 771    111              Y      5.6     Down             1
# 791    122              Y      4.2     Flat             1
# 850    145              N      6.2     Down             1
# 900    140              N      4.4     Down             1

# %%
df3 = df2[df2.Oldpeak<=(df2.Oldpeak.mean()+3*df.Oldpeak.std())]
df3.shape
# Out:
# (902, 12)

# %%
df.FastingBS.value_counts()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64

# %%
df3.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df3.ChestPainType.value_counts()
# Out:
# ChestPainType
# ASY    485
# NAP    201
# ATA    171
# TA      45
# Name: count, dtype: int64

# %%
df3.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df3.RestingECG.unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df3.ST_Slope.unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df3.ExerciseAngina.unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
df3.Sex.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df4=df3.copy()
df4.ChestPainType.replace(
{
    "ATA":0,
    "NAP":1,
    "ASY":2,
    "TA":3
},
inplace=True)
df4.RestingECG.replace(
{
  "Normal":1,
    "ST":2,
    "LVH":3
},
inplace=True)
df4.ST_Slope.replace(
{
   "Up":1,
    "Flat":2,
    "Down":3
},
inplace=True)

# %%
df4.head()
# Out:
#    Age Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40   M              0        140          289          0           1
# 1   49   F              1        160          180          0           1
# 2   37   M              0        130          283          0           2
# 3   48   F              2        138          214          0           1
# 4   54   M              1        150          195          0           1
#
#    MaxHR ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172              N      0.0         1             0
# 1    156              N      1.0         2             1
# 2     98              N      0.0         1             0
# 3    108              Y      1.5         2             1
# 4    122              N      0.0         1             0

# %%
df5=pd.get_dummies(df4,drop_first=True)
df5.head()
# Out:
#    Age  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# 0   40              0        140          289          0           1    172
# 1   49              1        160          180          0           1    156
# 2   37              0        130          283          0           2     98
# 3   48              2        138          214          0           1    108
# 4   54              1        150          195          0           1    122
#
#    Oldpeak  ST_Slope  HeartDisease  Sex_M  ExerciseAngina_Y
# 0      0.0         1             0   True             False
# 1      1.0         2             1  False             False
# 2      0.0         1             0   True             False
# 3      1.5         2             1  False              True
# 4      0.0         1             0   True             False

# %%
x = df5.drop("HeartDisease",axis='columns')
y = df5.HeartDisease

# %%
df5.describe()
# Out:
#               Age  ChestPainType   RestingBP  Cholesterol   FastingBS  \
# count  902.000000     902.000000  902.000000   902.000000  902.000000
# mean    53.487805       1.447894  131.854767   197.347007    0.232816
# std      9.444115       0.852659   17.682612   107.585613    0.422860
# min     28.000000       0.000000    0.000000     0.000000    0.000000
# 25%     47.000000       1.000000  120.000000   173.000000    0.000000
# 50%     54.000000       2.000000  130.000000   222.000000    0.000000
# 75%     60.000000       2.000000  140.000000   266.000000    0.000000
# max     77.000000       3.000000  185.000000   518.000000    1.000000
#
#        RestingECG       MaxHR     Oldpeak    ST_Slope  HeartDisease
# count  902.000000  902.000000  902.000000  902.000000    902.000000
# mean     1.597561  136.848115    0.857428    1.627494      0.548780
# std      0.802960   25.451226    1.013157    0.600442      0.497891
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[-1.42896269, -1.6990351 ,  0.46089071, ..., -1.0456339 ,
#          0.51485643, -0.82065181],
#        [-0.47545956, -0.52558207,  1.5925728 , ...,  0.62072967,
#         -1.94228905, -0.82065181],
#        [-1.74679706, -1.6990351 , -0.10495034, ..., -1.0456339 ,
#          0.51485643, -0.82065181],
#        ...,
#        [ 0.37209878,  0.64787097, -0.10495034, ...,  0.62072967,
#          0.51485643,  1.21854359],
#        [ 0.37209878, -1.6990351 , -0.10495034, ...,  0.62072967,
#         -1.94228905, -0.82065181],
#        [-1.64085227, -0.52558207,  0.3477225 , ..., -1.0456339 ,
#          0.51485643, -0.82065181]])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.8,random_state=30)

# %%
from sklearn.svm import SVC
model = SVC()
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 0.832409972299169

# %%
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
score=cross_val_score(DecisionTreeClassifier(),x,y,cv=5)
score
# Out:
# array([0.76243094, 0.78453039, 0.78888889, 0.77777778, 0.60555556])

# %%
score.mean()
# Out:
# 0.7438367096378146

# %%
from sklearn.ensemble import BaggingClassifier
bag_model=BaggingClassifier(
    estimator=SVC(),
    n_estimators=100,
    max_samples=0.8,
    random_state=0,
    oob_score=True
)
bag_model.fit(x_train,y_train)
bag_model.oob_score_
# Out:
# 0.8555555555555555

# %%
bag_model.score(x_train,y_train)
# Out:
# 0.9166666666666666
